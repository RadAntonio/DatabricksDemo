# %%
 print("Hello world")

# %%
# %sql
SELECT "hello world"

# %% [markdown]
# # title 1
# ## title 2
# ### title 3

# %%
# %run ./Includes/setup

# %%
print(full_name)

# %%
  # %fs ls 'databricks-datasets'

# %%
 dbutils.help()

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls("/databricks-datasets")
display(files)
